# %% [markdown]
# <a href="https://colab.research.google.com/github/astha-29/ML/blob/master/Mini_Project01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sales= pd.read_csv('advertising.csv')
sales
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
sales.shape
# Out:
# (200, 4)
# (200, 4)

# %%
sns.relplot(x='TV',y='Sales',hue='Radio',data=sales)

# %%
#line plot
sns.relplot(x='TV',y='Sales',data=sales,kind='line')

# %%
sns.relplot(x='Newspaper',y='Sales',hue='Radio',data=sales,size="Newspaper")

# %%
sns.relplot(x='Newspaper',y='Sales',data=sales,kind='line')

# %%
sns.relplot(x='Radio',y='Sales',hue='Radio',data=sales,size="Newspaper")

# %%
sns.relplot(x='Radio',y='Sales',data=sales,kind='line')

# %%
sns.distplot(sales.Sales,hist=False)

# %%
sns.distplot(sales.TV,hist=False)

# %%
sns.distplot(sales.Newspaper,hist=False)

# %%
sns.distplot(sales.Radio,hist=False)

# %%
from scipy import stats

# %%
sns.pairplot(sales)

# %%
# %matplotlib inline
sns.pairplot(sales,x_vars=['TV','Newspaper','Radio'],y_vars=['Sales'],size=3, aspect=0.7, kind='reg')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
x=sales.iloc[:,0:3].values
y=sales.iloc[:,3].values

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state =2)

# %%
x_train.shape
# Out:
# (140, 3)

# %%
x_test.shape
# Out:
# (60, 3)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
y_pred
# Out:
# array([15.8584001 , 10.25455219,  8.3433945 , 18.20597781, 18.24404472,
#        17.22677655,  8.88540573, 22.06145662, 12.56591147, 20.91199861,
#         9.80180521, 20.17988033, 10.76506947,  9.31801269, 17.12326355,
#        10.61197768,  8.82613242, 17.4148004 , 18.27755197, 19.35562321,
#        18.91947218, 19.34912455, 11.32777397, 10.89230486, 17.88617384,
#        14.5807791 , 16.6335762 ,  9.38704301, 18.77527466, 17.10618533,
#        19.97740506, 16.4226044 , 15.81783294, 14.13744233,  8.15700828,
#        12.19303194, 21.91220851, 21.439974  , 19.44373753, 19.63736243,
#        22.73481375, 17.50903243, 21.92044496, 15.07866493, 21.44389522,
#        19.10169368, 17.92298552,  8.94609413, 10.47446887, 10.48082118,
#        13.83216009, 17.27350066, 18.91227953, 18.1543629 ,  9.40322845,
#        15.83433527,  8.99652241,  5.32107233,  7.88454671, 25.0400331 ])

# %%
y_test
# Out:
# array([17.1, 10.5,  8.7, 18.4, 19.6, 20.2, 12.6, 20.2, 12.6, 17.8,  9.2,
#        19.4, 13.7,  6.6, 16.5, 12. ,  8.5, 16.5, 20.9, 19. , 20.5, 17. ,
#        11.8, 10.8, 16.9, 16.7, 16.1, 11.3, 19.8, 16.6, 16.8, 16. , 15.6,
#        13.2,  5.3, 12.4, 24.7, 20.2, 17.7, 21.2, 20.8, 18. , 21.8, 15.2,
#        19.8, 19.2, 17.1,  1.6, 10.9,  7.2, 12.9, 16.7, 17.4, 17.3,  9.7,
#        16.7, 11. ,  4.8,  7.6, 27. ])

# %%
from sklearn import metrics
metrics.r2_score(y_test,y_pred)*100 #Accuracy
# Out:
# 86.69425938331328

# %%
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 3.422684076942014
